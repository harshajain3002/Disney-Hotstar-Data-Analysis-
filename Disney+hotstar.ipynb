# %% [markdown]
# <a href="https://colab.research.google.com/github/harshajain3002/Disney-Hotstar-Data-Analysis-/blob/main/Disney%2Bhotstar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
disney_plus = pd.read_csv("disney_plus_shows.csv")

# %%
disney_plus.head()
# Out:
#      imdb_id                                       title  \
# 0  tt0147800                  10 Things I Hate About You
# 1  tt7019028                        101 Dalmatian Street
# 2  tt0115433                              101 Dalmatians
# 3  tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4  tt0211181                              102 Dalmatians
#
#                                                 plot    type  rated   year  \
# 0  A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...  series    NaN  2018–
# 2  An evil high-fashion designer plots to steal D...   movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...   movie      G   2000
#
#    released_at           added_at  runtime  \
# 0  31 Mar 1999  November 12, 2019   97 min
# 1  25 Mar 2019  February 28, 2020      NaN
# ...

# %%
# Using dataframe disney_plus: info

disney_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      894 non-null    object
#  1   title        894 non-null    object
#  2   plot         866 non-null    object
#  3   type         894 non-null    object
#  4   rated        742 non-null    object
#  5   year         894 non-null    object
#  6   released_at  874 non-null    object
#  7   added_at     992 non-null    object
#  8   runtime      838 non-null    object
#  9   genre        885 non-null    object
#  10  director     689 non-null    object
#  11  writer       743 non-null    object
#  12  actors       870 non-null    object
#  13  language     856 non-null    object
#  14  country      869 non-null    object
#  15  awards       556 non-null    object
#  16  metascore    292 non-null    float64
#  17  imdb_rating  879 non-null    float64
# ...

# %%
# shape

disney_plus.shape
# Out:
# (992, 19)

# %%
disney_plus.describe()
# Out:
#         metascore  imdb_rating
# count  292.000000   879.000000
# mean    62.061644     6.656428
# std     15.776455     1.020352
# min     19.000000     1.500000
# 25%     51.000000     6.100000
# 50%     61.000000     6.700000
# 75%     73.000000     7.400000
# max     99.000000     9.700000

# %%
disney_plus.isnull().sum()
# Out:
# imdb_id         98
# title           98
# plot           126
# type            98
# rated          250
# year            98
# released_at    118
# added_at         0
# runtime        154
# genre          107
# director       303
# writer         249
# actors         122
# language       136
# country        123
# awards         436
# metascore      700
# imdb_rating    113
# imdb_votes     113
# dtype: int64

# %%
disney_plus.duplicated().sum()
# Out:
# 74

# %% [markdown]
# disney_plus =disney_plus.drop_duplicates()
# disney_plus.duplicated().sum()

# %%
disney_plus.set_index('imdb_id',inplace=True)
disney_plus.head()
# Out:
#                                                 title  \
# imdb_id
# tt0147800                  10 Things I Hate About You
# tt7019028                        101 Dalmatian Street
# tt0115433                              101 Dalmatians
# tt0324941  101 Dalmatians 2: Patch's London Adventure
# tt0211181                              102 Dalmatians
#
#                                                         plot    type  rated  \
# imdb_id
# tt0147800  A pretty, popular teenager can't go out on a d...   movie  PG-13
# tt7019028  This series follows the lives of Delilah and D...  series    NaN
# tt0115433  An evil high-fashion designer plots to steal D...   movie      G
# tt0324941  Being one of 101 takes its toll on Patch, who ...   movie      G
# tt0211181  Cruella DeVil gets out of prison and goes afte...   movie      G
#
#             year  released_at           added_at  runtime  \
# imdb_id
# tt0147800   1999  31 Mar 1999  November 12, 2019   97 min
# ...

# %%
disney_plus.dropna(subset=['title', 'type'], inplace=True)

# %%
disney_plus.title
# Out:
# imdb_id
# tt0147800                    10 Things I Hate About You
# tt7019028                          101 Dalmatian Street
# tt0115433                                101 Dalmatians
# tt0324941    101 Dalmatians 2: Patch's London Adventure
# tt0211181                                102 Dalmatians
#                                 ...
# tt3544734                                        Zapped
# tt0186726               Zenon: Girl of the 21st Century
# tt0271271                             Zenon: The Zequel
# tt0379060                                     Zenon: Z3
# tt2948356                                      Zootopia
# Name: title, Length: 894, dtype: object

# %%
disney_plus.year
# Out:
# imdb_id
# tt0147800     1999
# tt7019028    2018–
# tt0115433     1996
# tt0324941     2002
# tt0211181     2000
#              ...
# tt3544734     2014
# tt0186726     1999
# tt0271271     2001
# tt0379060     2004
# tt2948356     2016
# Name: year, Length: 894, dtype: object

# %%
disney_plus['year'] = pd.to_numeric(disney_plus['year'], errors='coerce')
plt.figure(figsize=(10, 6))
sns.histplot(disney_plus['year'].dropna(), bins=20, kde=False, color='blue')
plt.title("Year-wise Distribution of Content")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
disney_plus.released_at
# Out:
# imdb_id
# tt0147800    31 Mar 1999
# tt7019028    25 Mar 2019
# tt0115433    27 Nov 1996
# tt0324941    21 Jan 2003
# tt0211181    22 Nov 2000
#                 ...
# tt3544734    23 Jun 2014
# tt0186726    23 Jan 1999
# tt0271271    12 Jan 2001
# tt0379060    11 Jun 2004
# tt2948356    04 Mar 2016
# Name: released_at, Length: 894, dtype: object

# %%
disney_plus. runtime.unique()
# Out:
# array(['97 min', nan, '103 min', '74 min', '100 min', '90 min', '127 min',
#        '95 min', '78 min', '89 min', '7 min', '88 min', '48 min',
#        '109 min', '128 min', '81 min', '69 min', '75 min', '108 min',
#        '93 min', '30 min', '84 min', '79 min', '25 min', '94 min',
#        '120 min', '70 min', '5 min', '162 min', '8 min', '106 min',
#        '92 min', '72 min', '117 min', '99 min', '96 min', '21 min',
#        '22 min', '102 min', '27 min', '23 min', '55 min', '85 min',
#        '101 min', '36 min', '2 min', '6 min', '98 min', '83 min',
#        '73 min', '9 min', '105 min', '47 min', '42 min', '111 min',
#        '112 min', '82 min', '87 min', '15 min', '12 min', '51 min',
#        '10 min', '63 min', '104 min', '1 h', '76 min', '11 min',
#        '110 min', '77 min', '45 min', '44 min', '46 min', '24 min',
#        '151 min', '125 min', '3 min', '29 min', '4 min', '118 min',
#        '60 min', '31 min', '91 min', '86 min', '80 min', '113 min',
# ...

# %%
print("\nTop 10 Genres:")
top_genres = disney_plus['genre'].value_counts().head(10)
print(top_genres)
# Out:
# Top 10 Genres:
# genre
# Documentary                                      53
# Comedy, Family                                   27
# Comedy, Drama, Family                            19
# Action, Adventure, Sci-Fi                        17
# Animation, Short, Comedy, Family                 17
# Animation, Adventure, Comedy, Family, Fantasy    17
# Comedy, Family, Fantasy                          16
# Animation, Adventure, Comedy, Family             14
# Animation, Comedy, Family                        12
# Comedy, Family, Sci-Fi                           12
# Name: count, dtype: int64

# %%
# Plot top genres
plt.figure(figsize=(10, 6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette="viridis")
plt.title("Top 10 Genres")
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-daaee2ea1bcc> in <cell line: 2>()
#       1 # Plot top genres
# ----> 2 plt.figure(figsize=(10, 6))
#       3 sns.barplot(x=top_genres.values, y=top_genres.index, palette="viridis")
#       4 plt.title("Top 10 Genres")
#       5 plt.xlabel("Count")
#
# NameError: name 'plt' is not defined

# %%
disney_movies = disney_plus[disney_plus.type == 'Movie']
disney_shows = disney_plus[disney_plus.type == 'TV Show']

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.subplots()
disney_plus.type.value_counts().plot(ax=ax, kind='pie')
ax.set_ylabel("")
ax.set_title("Movies & Shows")
plt.show()

# %%
#  country

# Assuming you have a 'country' column in your DataFrame
# If not, replace 'country' with the actual column name containing country information

if 'country' in disney_plus.columns:
  print("\nTop 10 Countries:")
  top_countries = disney_plus['country'].value_counts().head(10)
  print(top_countries)

  # Plot top countries
  plt.figure(figsize=(10, 6))
  sns.barplot(x=top_countries.values, y=top_countries.index, palette="viridis")
  plt.title("Top 10 Countries")
  plt.xlabel("Count")
  plt.ylabel("Country")
  plt.show()
else:
  print("No 'country' column found in the DataFrame.")
# Out:
# Top 10 Countries:
# country
# USA               735
# USA, Canada        19
# Canada, USA        14
# USA, UK            11
# UK                 11
# USA, Australia      7
# UK, USA             7
# Australia, USA      3
# USA, France         3
# Denmark, China      3
# Name: count, dtype: int64
# <ipython-input-40-85bb0b8a8275>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette="viridis")

# %%
# Directors with the most content
print("\nTop 10 directors:")
top_directors = disney_plus['director'].value_counts().head(10)
print(top_directors)
# Out:
# Top 10 directors:
# director
# Jack Hannah         16
# Paul Hoen           15
# Wilfred Jackson     11
# Robert Stevenson    10
# Vincent McEveety    10
# Kenny Ortega         9
# Duwayne Dunham       8
# Stuart Gillard       8
# James Algar          8
# Norman Tokar         7
# Name: count, dtype: int64

# %%
# imdb rating

print("\nTop 10 Highest Rated Shows/Movies:")
top_rated = disney_plus.sort_values('imdb_rating', ascending=False).head(10)
print(top_rated[['title', 'imdb_rating']])
# Out:
# Top 10 Highest Rated Shows/Movies:
#                                                      title  imdb_rating
# imdb_id
# tt7678620                                            Bluey          9.7
# tt9331982                           The Imagineering Story          9.1
# tt1865718                                    Gravity Falls          8.9
# tt11151654                            Dr. T, Lone Star Vet          8.9
# tt4555736                                   Muppet Moments          8.8
# tt7651892                                 One Strange Rock          8.8
# tt0096697                                     The Simpsons          8.7
# tt8111088                                  The Mandalorian          8.7
# tt10366494                     Lost Cities with Albert Lin          8.7
# tt0080684   Star Wars: Episode V - The Empire Strikes Back          8.7

# %%
# imdb distribution

import seaborn as sns

# Assuming you have a 'imdb_rating' column in your DataFrame
# If not, replace 'imdb_rating' with the actual column name containing IMDB ratings

if 'imdb_rating' in disney_plus.columns:
  plt.figure(figsize=(10, 6))
  sns.histplot(disney_plus['imdb_rating'].dropna(), bins=20, kde=True, color='green')
  plt.title("IMDB Rating Distribution")
  plt.xlabel("IMDB Rating")
  plt.ylabel("Count")
  plt.show()

else:
  print("No 'imdb_rating' column found in the DataFrame.")

# %%
disney_plus['metascore'].fillna(disney_plus['metascore'].mean(), inplace=True)
disney_plus.metascore
# Out:
# imdb_id
# tt0147800    70.000000
# tt7019028    62.061644
# tt0115433    49.000000
# tt0324941    62.061644
# tt0211181    35.000000
#                ...
# tt3544734    62.061644
# tt0186726    62.061644
# tt0271271    62.061644
# tt0379060    62.061644
# tt2948356    78.000000
# Name: metascore, Length: 894, dtype: float64

# %%
# @title metascore

from matplotlib import pyplot as plt
disney_plus['metascore'].plot(kind='hist', bins=20, title='metascore')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title metascore vs imdb_rating

from matplotlib import pyplot as plt
disney_plus.plot(kind='scatter', x='metascore', y='imdb_rating', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
